# %% [markdown]
# ## Final Project: Book Recommender

# %% [markdown]
# ### Phase 1: Web-Scraping

# %% [markdown]
# For the scraping requirement for this project, I've decided to go ahead and use Selenium. The benefit of using Selenium, is that it doesn't put in requests or calls to the desired website but instead gathers all of the data at scale.
# <br>
# <br>
# For the web-scraping portion of this project, I've decided to use the Barnes & Nobles top 100 Bestsellers.

# %% [markdown]
# ##### Importing correct librairies

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time

import requests
from bs4 import BeautifulSoup as bs4
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
def click(x):
    button = driver.find_element(By.XPATH, x)
    time.sleep(2)
    button.click()

# %% [markdown]
# The webpage B&N Top 100 Bestsellers had 5 pages, therefore running this code to include all 5 pages when web scraping

# %%
url_base = "https://www.barnesandnoble.com/b/books/_/N-1fZ29Z8q8?Nrpp=20&page="
pages = []
for i in range(1,6):
    page = url_base + str(i)
    pages.append(page)
pages
# Out:
# ['https://www.barnesandnoble.com/b/books/_/N-1fZ29Z8q8?Nrpp=20&page=1',
#  'https://www.barnesandnoble.com/b/books/_/N-1fZ29Z8q8?Nrpp=20&page=2',
#  'https://www.barnesandnoble.com/b/books/_/N-1fZ29Z8q8?Nrpp=20&page=3',
#  'https://www.barnesandnoble.com/b/books/_/N-1fZ29Z8q8?Nrpp=20&page=4',
#  'https://www.barnesandnoble.com/b/books/_/N-1fZ29Z8q8?Nrpp=20&page=5']

# %%
page_source = []
url_list = []
for i in pages:
    options = Options()
    options.add_argument("--disable-notifications")
    options.add_argument('--disable-gpu')
    options.add_argument('user-agent=fake-useragent')

    driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.maximize_window()
    driver.get(i)
    time.sleep(1)
    html = driver.page_source #this will only get the page_sources and save it in HTML
    # page_source.append(html) # saving page_source
    time.sleep(1)
    soup = bs4(html)
    result = soup.find_all("li",{"class":"pb-s mt-m bd-bottom-disabled-gray record list-view-data"})
    for i in result:
        url = i.find("a").get("href")
        url_list.append(url)
    time.sleep(1)
    driver.close()
# Out:
# [WDM] - Downloading: 100%|█████████████████| 8.72M/8.72M [00:00<00:00, 11.5MB/s]

# %% [markdown]
# Checking the length of the URL List and appending the book details to the B&N URL

# %%
len(url_list)
# Out:
# 100

# %%
book_url = []
for i in url_list:
    i = "https://www.barnesandnoble.com" + i
    book_url.append(i)

# %%
book_url[1]
# Out:
# 'https://www.barnesandnoble.com/w/if-he-had-been-with-me-laura-nowlin/1112689781;jsessionid=47C2EB06DB113BF70D73545CF8DA1879.prodny_store01-atgap01?ean=9781728205489'

# %% [markdown]
# Creating a new list with the web-scraping details to be later used to put into a DataFrame

# %%
book_source = []
for i in book_url:
    options = Options()
    options.add_argument("--disable-notifications")
    options.add_argument('--disable-gpu')
    options.add_argument('user-agent=fake-useragent')

    driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.maximize_window()
    driver.get(i)
    time.sleep(1)
    html = driver.page_source #this will only get the page_sources and save it in HTML
    soup = bs4(html)
    book_source.append(soup) # saving page_source

# %%
print(book_source)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
len(book_source)
# Out:
# 100

# %% [markdown]
# ##### Shown below are additional steps in how I retracted the information from book_source.

# %%
book_source[0].find_all('h1')[0].get_text()
# Out:
# 'Love, Pamela (Signed Book)'

# %%
book_source[0].find_all('span',class_= "contributors pdp-book-author")[0].select('input')[0]['value']
#key-contributors > a
# Out:
# 'Pamela Anderson'

# %%
float(book_source[0].find_all('div',class_="bv_avgRating_component_container notranslate")[0].get_text())
# Out:
# 5.0

# %%
book_source[4].find_all('span',class_="related-sub-text pt-xxs")[0].get_text()
# Out:
# ' 2023 Barnes & Noble Book Club Selections'

# %%
book_source[0].find_all('img',class_ = "full-shadow ResolveComplete pdpImgLoadCompleted")[0]["src"]
# Out:
# 'https://prodimage.images-bn.com/lf?set=key%5Bresolve.pixelRatio%5D,value%5B1%5D&set=key%5Bresolve.width%5D,value%5B600%5D&set=key%5Bresolve.height%5D,value%5B10000%5D&set=key%5Bresolve.imageFit%5D,value%5Bcontainerwidth%5D&set=key%5Bresolve.allowImageUpscaling%5D,value%5B0%5D&set=key%5Bresolve.format%5D,value%5Bwebp%5D&source=url%5Bhttps://prodimage.images-bn.com/pimages/9780063317420_p0_v2_s600x595.jpg%5D&scale=options%5Blimit%5D,size%5B600x10000%5D&sink=format%5Bwebp%5D'

# %%
book_source[0].find_all('div',class_="pt-m mb-l bs-ov-section")[0].get_text()
# Out:
# '\n\n\nOverview\n\n\n\nTO LIVEAND DREAMIS A WICKED DANCE.MY DREAMS OFTEN COME TRUE—A CURSE,AND A BLESSING.PAMELA ANDERSON’s blond bombshell image was ubiquitous in the 1990s. Discovered in the stands during a Canadian football game, she was quickly launched into superstardom, becoming Playboy’s favorite cover girl and an emblem of Hollywood glamour and sex appeal. Yet the Pamela Anderson we think we know was created through happenstance rather than careful cultivation. Love, Pamela brings forth her true story: that of a small-town girl getting tangled up in her own dream.Growing up on Vancouver Island, the daughter of young, wild, and unwittingly stylish parents, Pamela lived a hardscrabble childhood but developed a deep love for nature, populating her world with misfits, apparitional friends, and injured animals. Eventually overcoming her natural shyness, Pamela’s restless imagination propelled her into a life few can dream of, from the beaches of Malibu to the coveted scene at the Playboy Mansion. As her star rose, she found herself a fixture of tabloid fodder, at the height of an era when paparazzi tactics were bent on destroying a person’s image and self-esteem.Pamela forged ahead with grace, finding sanctuary in her love of art and literature, and emerged a devoted mother and activist. Now, having returned to the island of her childhood, after a memorable run starring as Roxie in Chicago on Broadway, Pamela is telling her story, a story of an irrepressible free spirit coming home and discovering herself anew at every turn. With vivid prose interspersed with bursts of original poetry, Love, Pamela is a pensive, layered, and unforgettable memoir.\n\n\n\n\n\n'

# %%
book_source[0].find_all('table',class_="plain centered")[0].select("span")[0].get_text()
# Out:
# 'HarperCollins Publishers'

# %%
book_source[0].find_all('tr')[2].select('td')[0].get_text()
# Out:
# '01/31/2023'

# %%
book_source[0].find_all('tr')[4].select('td')[0].get_text()
# Out:
# '256'

# %%
book_source[0].find_all('div',class_="tab-container")[0].select('td')[0].get_text()
# Out:
# '9780063317420'

# %% [markdown]
# ##### Appending the individual lists for  title, genre, rating, author, isbn, publisher, description, page_count, year published, image_link from the book_source(which was scraped from the B&N website)

# %%
title = []
genre = []
rating = []
author = []
isbn = []
publisher = []
description = []
page_count = []
year_published = []
image_link = []

for i in book_source:
    
    a = i.find_all('h1')[0].get_text()
    title.append(a)
    b = i.find_all('span',class_= "contributors pdp-book-author")[0].select('input')[0]['value']
    author.append(b)
    try:
        c = float(i.find_all('div',class_="bv_avgRating_component_container notranslate")[0].get_text())
    except:
        c = 0.0
    rating.append(c)
    try:
        d = i.find_all('span',class_="related-sub-text pt-xxs")[0].get_text()
    except:
        d = "NaN"
    genre.append(d)
    
    try:    
        e = i.find_all('div',class_="tab-container")[0].select('td')[0].get_text()
    except:
        e = 0.0
    isbn.append(e)
    
    try: 
        f = i.find_all('div',class_="pt-m mb-l bs-ov-section")[0].get_text()
    except:
        f ="NaN"
    description.append(f)
    
    try:
        g = i.find_all('tr')[4].select('td')[0].get_text()
    except:
        g = 0.0
    page_count.append(g)
    
    try:
        h = i.find_all('tr')[2].select('td')[0].get_text()
    except:
        h = 0.0
    year_published.append(h)
    
    try:
        x = i.find_all('img',class_ = "full-shadow ResolveComplete pdpImgLoadCompleted")[0]["src"]
    except:
        x = "NaN"
    image_link.append(x)
    
    try:
        j = i.find_all('table',class_="plain centered")[0].select("span")[0].get_text()
    except:
        j = "NaN"
    publisher.append(j)

print(title)
print(author)
print(rating)
print(genre)
print(isbn)
print(publisher)
print(description)
print(page_count)
print(year_published)
print(image_link)
# Out:
# ['Love, Pamela (Signed Book)', 'If He Had Been with Me', 'And There He Kept Her: A Novel', 'Chain of Thorns', 'The Snow Hare (Barnes & Noble Book Club Edition)', 'It Ends with Us', 'Spare', "Go Get 'Em, Tiger! (A Hello!Lucky Book) (Barnes & Noble Edition)", 'Final Offer', 'The Creative Act: A Way of Being', 'Lessons in Chemistry (B&N Exclusive Edition) (B&N Book of the Year)', 'It Starts with Us: A Novel', 'The Galveston Diet: The Doctor-Developed, Patient-Proven Plan to Burn Fat and Tame Your Hormonal Symptoms', 'Kingdom of Ash (Throne of Glass Series #7)', 'Twisted Hate (Twisted Series #3)', 'The Way I Used to Be', 'A Court of Mist and Fury (A Court of Thorns and Roses Series #2)', 'A Court of Wings and Ruin (A Court of Thorns and Roses Series #3)', 'Hooky Volume 3', 'Becoming Free Indeed: My Story of Disentangling Faith from Fear', 'Twisted Lies (Twisted Series #4)', 'Look Out for the Little Guy', 'Twisted Games (Twisted Series #2)', 'Cooking for the Culture: Recipes and Stories from the New Orleans Streets to the Table', 'A Court of Thorns and Roses (A Court of Thorns and Roses Series #1)', 'A Curse for True Love (B&N Exclusive Edition)', 'Tower of Dawn (Throne of Glass Series #6)', 'Verity', 'Queen of Shadows (Throne of Glass Series #4)', 'A Court of Frost and Starlight (A Court of Thorns and Roses Series)', 'A Court of Silver Flames (A Court of Thorns and Roses Series #4)', 'Terms and Conditions', 'The Nazi Conspiracy: The Secret Plot to Kill Roosevelt, Stalin, and Churchill', 'The Sun and Its Shade (B&N Exclusive Edition)', 'Throne of Glass (Throne of Glass Series #1)', 'Sex Talks: The Five Conversations That Will Transform Your Love Life', 'Heir of Fire (Throne of Glass Series #3)', 'Crown of Midnight (Throne of Glass Series #2)', 'Missing Dead Girls', 'The House of Wolves', 'The Inheritance Games (Inheritance Games Series #1)', 'The Fine Print', 'Heir of Fire (Throne of Glass Series #3)', 'Twisted Love (Twisted Series #1)', 'Tomorrow, and Tomorrow, and Tomorrow', 'Queen of Shadows (Throne of Glass Series #4)', 'Unravel Me (Shatter Me Series #2)', 'Love and Other Words', 'The Silent Patient', 'The House in the Cerulean Sea (B&N Exclusive Edition)', 'Things We Never Got Over', 'Harry Potter and the Prisoner of Azkaban: MinaLima Edition (Harry Potter Series #3)', 'Better Than the Movies', 'Shatter Me (Shatter Me Series #1)', 'The Housemaid', 'The Chalice of the Gods (Signed B&N Exclusive Book) (Percy Jackson and the Olympians)', 'The Sweet Spot: A Novel', 'Empire of Storms (Throne of Glass Series #5)', 'Daisy Jones & The Six', 'Heart Bones', 'Atomic Habits: An Easy & Proven Way to Build Good Habits & Break Bad Ones', 'I Am the Storm: Inspiring Stories of People Who Fight Against Overwhelming Odds', 'Under the Whispering Door (B&N Exclusive Edition)', 'Encore in Death: An Eve Dallas Novel (In Death Series #56)', 'Empire of Storms (Throne of Glass Series #5)', 'Tower of Dawn (Throne of Glass Series #6)', 'Kingdom of Ash (Throne of Glass Series #7)', 'Lore Olympus: Volume Four', "The Assassin's Blade: The Throne of Glass Novellas", "The Citizen's Guide to Fifth Generation Warfare", 'Never Give an Inch: Fighting for the America I Love', 'The Seven Husbands of Evelyn Hugo: A Novel', 'Threadneedle (Threadneedle Series #1)', "You're My Little Cuddle Bug", 'The Perfect Marriage', 'Exiles: A Novel', 'The Stolen Heir: A Novel of Elfhame (B&N Exclusive Edition)', 'The 48 Laws of Power', 'The 1619 Project: A New Origin Story', 'Crown of Midnight (Throne of Glass Series #2)', 'Ignite Me (Shatter Me Series #3)', 'The House in the Pines: A Novel', 'Things We Hide from the Light', 'The Cabinet of Dr. Leng (Signed Book)', 'The Light We Carry: Overcoming in Uncertain Times', 'The Serpent and the Wings of Night', 'The Body Keeps the Score: Brain, Mind, and Body in the Healing of Trauma', 'Murder Your Employer: The McMasters Guide to Homicide (B&N Exclusive Edition)', "Archer's Voice", "I'll Love You Till the Cows Come Home: A Valentine's D ...
# ['Pamela Anderson', 'Laura Nowlin', 'Joshua Moehling', 'Cassandra Clare', 'Paula Lichtarowicz', 'Colleen Hoover', 'Prince Harry, The Duke of Sussex', '', 'Lauren Asher', 'Rick Rubin', 'Bonnie Garmus', 'Colleen Hoover', 'Mary Claire Haver MD', 'Sarah J. Maas', 'Ana Huang', 'Amber Smith', 'Sarah J. Maas', 'Sarah J. Maas', '', 'Jinger Vuolo', 'Ana Huang', 'Scott Lang', 'Ana Huang', 'Toya Boudy', 'Sarah J. Maas', 'Stephanie Garber', 'Sarah J. Maas', 'Colleen Hoover', 'Sarah J. Maas', 'Sarah J. Maas', 'Sarah J. Maas', 'Lauren Asher', '', 'Piper CJ', 'Sarah J. Maas', '', 'Sarah J. Maas', 'Sarah J. Maas', 'Sara Walters', '', 'Jennifer Lynn Barnes', 'Lauren Asher', 'Sarah J. Maas', 'Ana Huang', 'Gabrielle Zevin', 'Sarah J. Maas', 'Tahereh Mafi', 'Christina Lauren', 'Alex Michaelides', 'TJ Klune', 'Lucy Score', '', 'Lynn Painter', 'Tahereh Mafi', 'Freida McFadden', 'Rick Riordan', 'Amy Poeppel', 'Sarah J. Maas', 'Taylor Jenkins Reid', 'Colleen Hoover', 'James Clear', 'Janice Dean', 'TJ Klune', 'J. D. Robb', 'Sarah J. Maas', 'Sarah J. Maas', 'Sarah J. Maas', 'Rachel Smythe', 'Sarah J. Maas', '', 'Mike Pompeo', 'Taylor Jenkins Reid', 'Cari Thomas', '', 'Jeneva Rose',
# ['HarperCollins Publishers', 'Sourcebooks', 'Sourcebooks', 'Margaret K. McElderry Books', 'Little, Brown and Company', 'Atria Books', 'Random House Publishing Group', 'ABRAMS', 'Sourcebooks', 'Penguin Publishing Group', 'Knopf Doubleday Publishing Group', 'Atria Books', 'Harmony/Rodale', 'Bloomsbury USA', 'Sourcebooks', 'Margaret K. McElderry Books', 'Bloomsbury USA', 'Bloomsbury USA', 'HarperCollins Publishers', 'Nelson, Thomas, Inc.', 'Sourcebooks', 'Disney Publishing Group', 'Sourcebooks', 'Countryman Press, The', 'Bloomsbury USA', 'Flatiron Books', 'Bloomsbury USA', 'Grand Central Publishing', 'Bloomsbury USA', 'Bloomsbury USA', 'Bloomsbury USA', 'Sourcebooks', 'Flatiron Books', 'Sourcebooks', 'Bloomsbury USA', 'S&S/Simon Element', 'Bloomsbury USA', 'Bloomsbury USA', 'Sourcebooks', 'Little, Brown and Company', 'Little, Brown Books for Young Readers', 'Sourcebooks', 'Bloomsbury USA', 'Sourcebooks', 'Knopf Doubleday Publishing Group', 'Bloomsbury USA', 'HarperCollins Publishers', 'Gallery Books', 'Celadon Books', 'Tom Doherty Associates', 'Sourcebooks', 'Scholastic, Inc.', 'Simon & Schuster Books For Young Readers', 'HarperCollins Publishers', 'Grand Central Publishing', 'Disney Publishing Group', 'Atria/Emily Bestler Books', 'Bloomsbury USA', 'Random House Publishing Group', 'Atria Books', 'Penguin Publishing Group', 'HarperCollins Publishers', 'Tom Doherty Associates', "St. Martin's Publishing Group", 'Bloomsbury USA', 'Bloomsbury USA', 'Bloomsbury USA', 'Random House Worlds', 'Bloomsbury USA', 'Boone Cutler Media Enterprise, LLC', 'HarperCollins Publishers', 'Washington Square Press', 'HarperCollins UK', 'Silver Dolphin Books', 'Open Road Integrated Media LLC', 'Flatiron Books', 'Little, Brown Books for Young Readers', 'Penguin Publishing Group', 'Random House Publishing Group', 'Bloomsbury USA', 'HarperCollins Publishers', 'Penguin Publishing Group', 'Sourcebooks', 'Grand Central Publishing', 'Crown Publishing Group', 'Carissa Broadbent', 'Penguin Publishing Group', 'Avid Reader Press / Simon & Schuster', 'Grand Central Publishing', 'HarperCollins Publishers', 'Sourcebooks', 'Random House Publishing Group', "Random House Children's Books", 'Bloomsbury USA', "St. Martin's Publishing Group", 'Atria Books', 'Knopf Doubleday Publishing Group', 'Random House Publishing Group', 'Simon & Schuster', 'Bloomsbury USA']
# ['\n\n\nOverview\n\n\n\nTO LIVEAND DREAMIS A WICKED DANCE.MY DREAMS OFTEN COME TRUE—A CURSE,AND A BLESSING.PAMELA ANDERSON’s blond bombshell image was ubiquitous in the 1990s. Discovered in the stands during a Canadian football game, she was quickly launched into superstardom, becoming Playboy’s favorite cover girl and an emblem of Hollywood glamour and sex appeal. Yet the Pamela Anderson we think we know was created through happenstance rather than careful cultivation. Love, Pamela brings forth her true story: that of a small-town girl getting tangled up in her own dream.Growing up on Vancouver Island, the daughter of young, wild, and unwittingly stylish parents, Pamela lived a hardscrabble childhood but developed a deep love for nature, populating her world with misfits, apparitional friends, and injured animals. Eventually overcoming her natural shyness, Pamela’s restless imagination propelled her into a life few can dream of, from the beaches of Malibu to the coveted scene at the Playboy Mansion. As her star rose, she found herself a fixture of tabloid fodder, at the height of an era when paparazzi tactics were bent on destroying a person’s image and self-esteem.Pamela forged ahead with grace, finding sanctuary in her love of art and literature, and emerged a devoted mother and activist. Now, having returned to the island of her childhood, after a memorable run starring as Roxie in Chicago on Broadway, Pamela is telling her story, a story of an irrepressible free spirit coming home and discovering herself anew at every turn. With vivid prose interspersed with bursts of original poetry, Love, Pamela is a pensive, layered, and unforgettable memoir.\n\n\n\n\n\n', "\n\n\nOverview\n\n\n\nA New York Times Bestseller*A BookTok Viral Sensation* An achingly authentic and raw portrait of love, regret, and the life-altering impact of the relationships we hold closest to us, this YA romance bestseller is perfect for fans of Colleen Hoover, Jenny Han, and You've Reached Sam. If he had been with me, everything would have been different…Autumn and Finn used to be inseparable. But then something changed. Or they changed. Now, they do their best to ignore each other.Autumn has her boyfriend Jamie, and her close-knit group of friends. And Finn has become that boy at school, the one everyone wants to be around.That still doesn't stop the way Autumn feels every time she and Finn cross paths, and the growing, nagging thought that maybe things could have been different. Maybe they should be together.But come August, things will change forever. And as time passes, Autumn will be forced to confront how else life might have been different if they had never parted ways…Captivating and heartbreaking, If He Had Been with Me is perfect for readers looking for:Contemporary teen romance booksUnputdownable & bingeworthy novelsComplex emotional YA storiesTikTok BooksJenny Han meets Dear Even HansonColleen Hover fans\n\n\n\n\n\n", '\n\n\nOverview\n\n\nNotes From Your BooksellerJoshua Moehling’s debut is on solid ground in its writing and suspense. The opening gambit is simple – two teens go missing after breaking into someone’s house.“Propulsive” and “atmospheric” are two words that will alternate in your brain as you read this novel about a Deputy Sheriff, his secrets and the small town that holds even more secrets. It\'s perfect for fans of Moehling’s fellow Minnesota writers John Sandford and William Kent Krueger.\n"Stellar debut." —Minneapolis Star Tribune"A dark and complex mystery that will consume you." —Julie Clark, New York Times bestselling author They thought he was a helpless old man. They were wrong.When two teenagers break into a house on a remote lake in search of prescription drugs, what starts as a simple burglary turns into a nightmare for all involved. Emmett Burr has secrets he\'s been keeping in his basement for more than two decades, and he\'ll do anything to keep his past from being revealed. As he gets the upper hand on his tormento ...
# ['256', '400', '336', '800', '384', '384', '7', 'B&N Exclusive Edition', '592', '10', '400', '336', '13', 'Reprint', '512', '384', '656', '736', '400', '20', '560', '256', '448', '24', '448', 'B&N Exclusive Edition', 'Reprint', '28', '672', '272', '784', '480', '33', 'B&N Exclusive Edition', '432', '36', '592', '448', '39', '40', '400', '448', '592', '352', '45', '672', '496', '48', '49', '416', '560', '400', '384', '368', '55', 'Signed Edition', '58', '704', '400', '61', '62', '63', '400', '384', '720', '688', '992', '416', '464', '71', '72', '400', '576', '18', '76', '368', 'B&N Exclusive Edition', '79', '80', 'First Edition', '416', '83', '592', 'Signed Edition', '86', '87', '88', '400', '400', '7,052', '352', '94', '448', '432', '97', '98', '832', '352', '101', '768']
                      "description":description,
                      "publisher":publisher,
                      "year_published":year_published,
                      "isbn":isbn,
                      "page_count":page_count,
                      "image_link":image_link})
                            
books
# Out:
#                                                 title              author  \
# 0                          Love, Pamela (Signed Book)     Pamela Anderson
# 1                              If He Had Been with Me        Laura Nowlin
# 2                      And There He Kept Her: A Novel     Joshua Moehling
# 3                                     Chain of Thorns     Cassandra Clare
# 4    The Snow Hare (Barnes & Noble Book Club Edition)  Paula Lichtarowicz
# ..                                                ...                 ...
# 95                                         November 9      Colleen Hoover
# 96                                      A Little Life    Hanya Yanagihara
# 97  The Bandit Queens (Barnes & Noble Book Club Ed...       Parini Shroff
# 98                               I'm Glad My Mom Died    Jennette McCurdy
# 99  House of Sky and Breath (Crescent City Series #2)       Sarah J. Maas
#
#     rating                                              genre  \
# 0      5.0                     Actors & Actresses - Biography
# 1      4.6              Dating and sex->Teen fiction->General
# 2      4.3                                    Crime Thrillers
# 3      4.0                Adventure->Historical->Teen fiction
# 4      0.0           2023 Barnes & Noble Book Club Selections
# ..     ...                                                ...
# 95     4.7                     Contemporary Romance - General
# 96     4.4                        2015 Kirkus Prize Finalists
# 97     4.3           2023 Barnes & Noble Book Club Selections
# 98     4.6                     Actors & Actresses - Biography
# 99     4.5   Barnes & Noble's Best Science Fiction & Fanta...
#
#                                           description  \
# 0   \n\n\nOverview\n\n\n\nTO LIVEAND DREAMIS A WIC...
# 1   \n\n\nOverview\n\n\n\nA New York Times Bestsel...
# 2   \n\n\nOverview\n\n\nNotes From Your Bookseller...
# 3   \n\n\nOverview\n\n\nNotes From Your Bookseller...
# 4   \n\n\nOverview\n\n\nNotes From Your Bookseller...
# ..                                                ...
# 95  \n\n\nOverview\n\n\nNotes From Your Bookseller...
# 96  \n\n\nOverview\n\n\nNotes From Your Bookseller...
# 97  \n\n\nOverview\n\n\nNotes From Your Bookseller...
# 98  \n\n\nOverview\n\n\nNotes From Your Bookseller...
# 99  \n\n\nOverview\n\n\nNotes From Your Bookseller...
#
#                            publisher year_published           isbn page_count  \
# 0           HarperCollins Publishers     01/31/2023  9780063317420        256
# 1                        Sourcebooks     11/01/2019  9781728205489        400
# 2                        Sourcebooks     01/31/2023  9781728275772        336
# 3        Margaret K. McElderry Books     01/31/2023  9781481431934        800
# 4          Little, Brown and Company     01/31/2023  9780316566902        384
# ..                               ...            ...            ...        ...
# 95                       Atria Books     11/10/2015  9781501110344         98
# 96  Knopf Doubleday Publishing Group     01/26/2016  9780804172707        832
# 97     Random House Publishing Group     01/03/2023  9780593722909        352
# 98                  Simon & Schuster     08/09/2022  9781982185824        101
# 99                    Bloomsbury USA     02/15/2022  9781635574074        768
#
#                                            image_link
# 0   https://prodimage.images-bn.com/lf?set=key%5Br...
# 1   https://prodimage.images-bn.com/lf?set=key%5Br...
# 2   https://prodimage.images-bn.com/lf?set=key%5Br...
# 3   https://prodimage.images-bn.com/lf?set=key%5Br...
# 4   https://prodimage.images-bn.com/lf?set=key%5Br...
# ..                                                ...
# 95  https://prodimage.images-bn.com/lf?set=key%5Br...
# 96  https://prodimage.images-bn.com/lf?set=key%5Br...
# 97  https://prodimage.images-bn.com/lf?set=key%5Br...
# 98  https://prodimage.images-bn.com/lf?set=key%5Br...
# 99  https://prodimage.images-bn.com/lf?set=key%5Br...
#
# [100 rows x 10 columns]

# %% [markdown]
# ##### Exporting the information to a CSV

# %%
books.to_csv('books.csv',index=False)

# %% [markdown]
# ##### Exporting a dataset that was obtained from Kaggle

# %%
data3 = pd.read_csv('books 3.csv')
data3
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 6805             Talks with Sri Nisargadatta Maharaj
# 6806                                             NaN
# 6807                                             NaN
# 6808                                             NaN
# 6809  Jeanette Winterson and the Politics of Reading
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                             Stephen R. Donaldson
# 3                                   Sidney Sheldon
# 4                              Clive Staples Lewis
# ...                                            ...
# 6805  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 6806                                 Khalil Gibran
# 6807                                  Ray Bradbury
# 6808                 Georg Wilhelm Friedrich Hegel
# 6809                        Helena Grice;Tim Woods
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                  American fiction
# 3                           Fiction
# 4                    Christian life
# ...                             ...
# 6805                     Philosophy
# 6806                      Mysticism
# 6807                   Book burning
# 6808                        History
# 6809             Literary Criticism
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=OmQaw...
# 3     http://books.google.com/books/content?id=FKo2T...
# 4     http://books.google.com/books/content?id=XhQ5X...
# ...                                                 ...
# 6805  http://books.google.com/books/content?id=Fv_JP...
# 6806  http://books.google.com/books/content?id=XcrVp...
# 6807                                                NaN
# 6808  http://books.google.com/books/content?id=Vy7Sk...
# 6809  http://books.google.com/books/content?id=2lVyR...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     Volume Two of Stephen Donaldson's acclaimed se...          1982.0
# 3     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 4     Lewis' work on the nature of love divides love...          2002.0
# ...                                                 ...             ...
# 6805  This collection of the timeless teachings of o...          1999.0
# 6806                                                NaN          1993.0
# 6807                                                NaN          2004.0
# 6808  Since the three volume edition ofHegel's Philo...          1981.0
# 6809  This is a jubilant and rewarding collection of...          1998.0
#
#       average_rating  num_pages  ratings_count
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.97      479.0          172.0
# 3               3.93      512.0        29532.0
# 4               4.15      170.0        33684.0
# ...              ...        ...            ...
# 6805            4.51      531.0          104.0
# 6806            4.08       74.0          324.0
# 6807            3.98      186.0         5733.0
# 6808            0.00      210.0            0.0
# 6809            3.70      136.0           10.0
#
# [6810 rows x 12 columns]

# %%
data3.shape
# Out:
# (6810, 12)

# %% [markdown]
# ##### Dropping unecessary columns and renaming and re-ordering columns to uniformely fit for data cleaning and ultimately modeling

# %%
data3 = data3.drop(columns= ['isbn10','subtitle','ratings_count'],axis=1)
data3 = pd.DataFrame(data3)
data3 = data3.rename(columns = {'authors':'author','categories':'genre','average_rating':'rating','thumbnail':'image_link','published_year':'year_published','isbn13':'isbn','num_pages':'page_count'})
data3 = data3[['title','author','rating','genre','description','year_published','isbn','page_count','image_link']]
data3
# Out:
#                           title                                        author  \
# 0                        Gilead                            Marilynne Robinson
# 1                  Spider's Web               Charles Osborne;Agatha Christie
# 2                  The One Tree                          Stephen R. Donaldson
# 3                Rage of angels                                Sidney Sheldon
# 4                The Four Loves                           Clive Staples Lewis
# ...                         ...                                           ...
# 6805                  I Am that  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 6806       Secrets Of The Heart                                 Khalil Gibran
# 6807             Fahrenheit 451                                  Ray Bradbury
# 6808   The Berlin Phenomenology                 Georg Wilhelm Friedrich Hegel
# 6809  'I'm Telling You Stories'                        Helena Grice;Tim Woods
#
#       rating                          genre  \
# 0       3.85                        Fiction
# 1       3.83  Detective and mystery stories
# 2       3.97               American fiction
# 3       3.93                        Fiction
# 4       4.15                 Christian life
# ...      ...                            ...
# 6805    4.51                     Philosophy
# 6806    4.08                      Mysticism
# 6807    3.98                   Book burning
# 6808    0.00                        History
# 6809    3.70             Literary Criticism
#
#                                             description  year_published  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     Volume Two of Stephen Donaldson's acclaimed se...          1982.0
# 3     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 4     Lewis' work on the nature of love divides love...          2002.0
# ...                                                 ...             ...
# 6805  This collection of the timeless teachings of o...          1999.0
# 6806                                                NaN          1993.0
# 6807                                                NaN          2004.0
# 6808  Since the three volume edition ofHegel's Philo...          1981.0
# 6809  This is a jubilant and rewarding collection of...          1998.0
#
#                isbn  page_count  \
# 0     9780002005883       247.0
# 1     9780002261982       241.0
# 2     9780006163831       479.0
# 3     9780006178736       512.0
# 4     9780006280897       170.0
# ...             ...         ...
# 6805  9788185300535       531.0
# 6806  9788185944609        74.0
# 6807  9788445074879       186.0
# 6808  9789027712059       210.0
# 6809  9789042003408       136.0
#
#                                              image_link
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=OmQaw...
# 3     http://books.google.com/books/content?id=FKo2T...
# 4     http://books.google.com/books/content?id=XhQ5X...
# ...                                                 ...
# 6805  http://books.google.com/books/content?id=Fv_JP...
# 6806  http://books.google.com/books/content?id=XcrVp...
# 6807                                                NaN
# 6808  http://books.google.com/books/content?id=Vy7Sk...
# 6809  http://books.google.com/books/content?id=2lVyR...
#
# [6810 rows x 9 columns]

# %% [markdown]
# ##### Exporting the dataset for future use

# %%
data3.to_csv('data3.csv',index=False)

# %% [markdown]
# ##### Running 2nd dataset that was obtained from Kaggle

# %%
data5 = pd.read_csv('books_1.Best_Books_Ever.csv')
data5
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice                    NaN
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 52473                                  Fractured             Fateful #2
# 52474                                    Anasazi      Sense of Truth #2
# 52475                                     Marked      Soul Guardians #1
# 52476                                Wayward Son                    NaN
# 52477                        Daughter of Helaman   Stripling Warrior #1
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 52473                   Cheri Schmidt (Goodreads Author)    4.00
# 52474                                      Emma Michaels    4.19
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
# 52477                    Misty Moncur (Goodreads Author)    4.02
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
# 1      There is a door at the end of a silent corrido...  English
# 2      The unforgettable novel of a childhood in a sl...  English
# 3      Alternate cover edition of ISBN 9780679783268S...  English
# 4      About three things I was absolutely positive.\...  English
# ...                                                  ...      ...
# 52473  The Fateful Trilogy continues with Fractured. ...  English
# 52474  'Anasazi', sequel to 'The Thirteenth Chime' by...  English
# 52475  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...  English
# 52476  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...  English
# 52477  Fighting in Helaman's army is Keturah's deepes...  English
#
#                 isbn                                             genres  \
# 0      9780439023481  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      9780439358071  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2      9999999999999  ['Classics', 'Fiction', 'Historical Fiction', ...
# 3      9999999999999  ['Classics', 'Fiction', 'Romance', 'Historical...
# 4      9780316015844  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# ...              ...                                                ...
# 52473  2940012616562  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...
# 52474  9999999999999                         ['Mystery', 'Young Adult']
# 52475  9781461017097  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...
# 52476  9781450755634  ['Fiction', 'Mystery', 'Historical Fiction', '...
# 52477  9781599554976  ['Lds Fiction', 'Historical Fiction', 'Young A...
#
#                                               characters  ...  \
# 0      ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  ...
# 1      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...  ...
# 2      ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...  ...
# 3      ['Mr. Bennet', 'Mrs. Bennet', 'Jane Bennet', '...  ...
# 4      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...  ...
# ...                                                  ...  ...
# 52473                                                 []  ...
# 52474                                                 []  ...
# 52475                                                 []  ...
# 52476                                                 []  ...
# 52477                                                 []  ...
#
#       firstPublishDate                                             awards  \
# 0                  NaN  ['Locus Award Nominee for Best Young Adult Boo...
# 1             06/21/03  ['Bram Stoker Award for Works for Young Reader...
# 2             07/11/60  ['Pulitzer Prize for Fiction (1961)', 'Audie A...
# 3             01/28/13                                                 []
# 4             10/05/05  ['Georgia Peach Book Award (2007)', 'Buxtehude...
# ...                ...                                                ...
# 52473              NaN                                                 []
# 52474  August 3rd 2011                                                 []
# 52475  March 15th 2011            ["Readers' Favorite Book Award (2011)"]
# 52476   April 5th 2011                                                 []
# 52477              NaN                                                 []
#
#       numRatings                                     ratingsByStars  \
# 0        6376780  ['3444695', '1921313', '745221', '171994', '93...
# 1        2507623  ['1593642', '637516', '222366', '39573', '14526']
# 2        4501075  ['2363896', '1333153', '573280', '149952', '80...
# 3        2998241  ['1617567', '816659', '373311', '113934', '767...
# 4        4964519  ['1751460', '1113682', '1008686', '542017', '5...
# ...          ...                                                ...
# 52473        871                  ['311', '310', '197', '42', '11']
# 52474         37                        ['16', '14', '5', '2', '0']
# 52475       6674             ['2109', '1868', '1660', '647', '390']
# 52476        238                      ['77', '78', '59', '19', '5']
# 52477        246                     ['106', '73', '42', '17', '8']
#
#       likedPercent                                            setting  \
# 0             96.0  ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1             98.0  ['Hogwarts School of Witchcraft and Wizardry (...
# 2             95.0               ['Maycomb, Alabama (United States)']
# 3             94.0  ['United Kingdom', 'Derbyshire, England (Unite...
# 4             78.0  ['Forks, Washington (United States)', 'Phoenix...
# ...            ...                                                ...
# 52473         94.0                                                 []
# 52474         95.0                                                 []
# 52475         84.0                                                 []
# 52476         90.0                                                 []
# 52477         90.0                                                 []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 0      https://i.gr-assets.com/images/S/compressed.ph...   2993816    30516
# 1      https://i.gr-assets.com/images/S/compressed.ph...   2632233    26923
# 2      https://i.gr-assets.com/images/S/compressed.ph...   2269402    23328
# 3      https://i.gr-assets.com/images/S/compressed.ph...   1983116    20452
# 4      https://i.gr-assets.com/images/S/compressed.ph...   1459448    14874
# ...                                                  ...       ...      ...
# 52473  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52474  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52475  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52476  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52477  https://i.gr-assets.com/images/S/compressed.ph...         0        1
#
#        price
# 0       5.09
# 1       7.38
# 2        NaN
# 3        NaN
# 4        2.1
# ...      ...
# 52473    NaN
# 52474    NaN
# 52475   7.37
# 52476   2.86
# 52477   5.20
#
# [52478 rows x 25 columns]

# %% [markdown]
# ##### Dropping the unecessary columns and renaming and re-ordering columns for them to unilateraly fit for future cleaning and modeling

# %%
data5 = data5.drop(columns= ['bookId','series','awards','language','characters','firstPublishDate','numRatings','ratingsByStars','likedPercent','setting','bbeScore','bbeVotes','price','bookFormat','edition','publisher'],axis=1)

data5 = pd.DataFrame(data5)
data5
data5 = data5.rename(columns = {'genres':'genre','coverImg':'image_link','publishDate':'year_published','pages':'page_count'})
data5 = data5[['title','author','rating','genre','description','year_published','isbn','page_count','image_link']]
data5
# Out:
#                                            title  \
# 0                               The Hunger Games
# 1      Harry Potter and the Order of the Phoenix
# 2                          To Kill a Mockingbird
# 3                            Pride and Prejudice
# 4                                       Twilight
# ...                                          ...
# 52473                                  Fractured
# 52474                                    Anasazi
# 52475                                     Marked
# 52476                                Wayward Son
# 52477                        Daughter of Helaman
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 52473                   Cheri Schmidt (Goodreads Author)    4.00
# 52474                                      Emma Michaels    4.19
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
# 52477                    Misty Moncur (Goodreads Author)    4.02
#
#                                                    genre  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2      ['Classics', 'Fiction', 'Historical Fiction', ...
# 3      ['Classics', 'Fiction', 'Romance', 'Historical...
# 4      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# ...                                                  ...
# 52473  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...
# 52474                         ['Mystery', 'Young Adult']
# 52475  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...
# 52476  ['Fiction', 'Mystery', 'Historical Fiction', '...
# 52477  ['Lds Fiction', 'Historical Fiction', 'Young A...
#
#                                              description      year_published  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...            09/14/08
# 1      There is a door at the end of a silent corrido...            09/28/04
# 2      The unforgettable novel of a childhood in a sl...            05/23/06
# 3      Alternate cover edition of ISBN 9780679783268S...            10/10/00
# 4      About three things I was absolutely positive.\...            09/06/06
# ...                                                  ...                 ...
# 52473  The Fateful Trilogy continues with Fractured. ...       May 28th 2011
# 52474  'Anasazi', sequel to 'The Thirteenth Chime' by...     August 5th 2011
# 52475  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...     March 18th 2011
# 52476  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...  September 1st 2011
# 52477  Fighting in Helaman's army is Keturah's deepes...        May 8th 2011
#
#                 isbn page_count  \
# 0      9780439023481        374
# 1      9780439358071        870
# 2      9999999999999        324
# 3      9999999999999        279
# 4      9780316015844        501
# ...              ...        ...
# 52473  2940012616562          0
# 52474  9999999999999        190
# 52475  9781461017097        280
# 52476  9781450755634        507
# 52477  9781599554976        201
#
#                                               image_link
# 0      https://i.gr-assets.com/images/S/compressed.ph...
# 1      https://i.gr-assets.com/images/S/compressed.ph...
# 2      https://i.gr-assets.com/images/S/compressed.ph...
# 3      https://i.gr-assets.com/images/S/compressed.ph...
# 4      https://i.gr-assets.com/images/S/compressed.ph...
# ...                                                  ...
# 52473  https://i.gr-assets.com/images/S/compressed.ph...
# 52474  https://i.gr-assets.com/images/S/compressed.ph...
# 52475  https://i.gr-assets.com/images/S/compressed.ph...
# 52476  https://i.gr-assets.com/images/S/compressed.ph...
# 52477  https://i.gr-assets.com/images/S/compressed.ph...
#
# [52478 rows x 9 columns]

# %% [markdown]
# ##### Exporting the last dataset

# %%
data5.to_csv('data5.csv', index=False)

# %% [markdown]
# ### LA FIN pour Phase 1
